# %% [markdown]
# # Loading Data

# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from src.data.loader import load_raw_data

#Load the data into a DataFrame variable
df_not_clean = load_raw_data()

df_not_clean.head()
# Out:
# Successfully located and loaded raw data from: data/raw/agent_tool_tasks.csv
#      task_uid  is_live_benchmark task_complexity task_domain  \
# 0  task_00001                  1             low       other
# 1  task_00002                  1             low      travel
# 2  task_00003                  1             low      travel
# 3  task_00004                  0            high       other
# 4  task_00005                  0          medium       other
#
#                                                query  \
# 0                                                air
# 1                                 what is your name?
# 2  Could you give me Python code that get 2 int t...
# 3  Find me the most recent art sculpture by James...
# 4  "Can you help me find a recipe that uses chick...
#
#                                           tool_names  query_word_count  \
# 0                                      ThinQ_Connect                 1
# 1                                get_current_weather                 4
# 2                                get_current_weather                14
# 3  get_zodiac_compatibility|local_nursery.find|ge...                13
# 4                        restaurant.find|recipe.find                58
#
#    num_available_tools  total_params  total_required_params  ...  \
# 0                    1             1                      1  ...
# 1                    1             2                      1  ...
# 2                    1             2                      1  ...
# 3                    4            10                      7  ...
# 4                    2             4                      3  ...
#
#    query_multi_intent_score  query_specificity_score query_unique_token_ratio  \
# 0                         0                      0.0                 1.000000
# 1                         0                      0.0                 1.000000
# 2                         1                      1.5                 1.000000
# 3                         0                      0.5                 1.000000
# 4                         7                      5.5                 0.627119
#
#   query_code_signal  query_temporal_signal  query_sensitive_data_signal  \
# 0                 0                      0                            0
# 1                 0                      0                            0
# 2                 1                      0                            0
# 3                 0                      0                            0
# 4                 0                      1                            0
#
#    param_type_diversity  structured_param_ratio  schema_rigidity_score  \
# 0                     1                    1.00                 0.7500
# 1                     1                    0.00                 0.4000
# 2                     1                    0.00                 0.4000
# 3                     4                    0.10                 0.4100
# 4                     3                    0.25                 0.6125
#
#    can_answer
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1
#
# [5 rows x 33 columns]

# %% [markdown]
# # Adding Mandatory Features

# %%
import pandas as pd
import sys

sys.path.append('../')
import src.features.mandatory as mandatory

df = mandatory.fill_missing_text(df_not_clean)

df_Mfeatures = mandatory.build_mandatory_features(df)

columns_to_check = [
    'query', 'query_avg_word_length', 
    'tool_names', 'tool_name_diversity', 
    'avg_params_per_tool','required_params_ratio',
    'query_mentions_number'
]
display(df_Mfeatures[columns_to_check].head())
# Out:
#                                                query  query_avg_word_length  \
# 0                                                air                    0.0
# 1                                 what is your name?                    0.0
# 2  Could you give me Python code that get 2 int t...                    0.0
# 3  Find me the most recent art sculpture by James...                    0.0
# 4  "Can you help me find a recipe that uses chick...                    0.0
#
#                                           tool_names  tool_name_diversity  \
# 0                                      ThinQ_Connect                    1
# 1                                get_current_weather                    1
# 2                                get_current_weather                    1
# 3  get_zodiac_compatibility|local_nursery.find|ge...                    4
# 4                        restaurant.find|recipe.find                    2
#
#    avg_params_per_tool  required_params_ratio  query_mentions_number
# 0                  1.0                   1.00                      0
# 1                  2.0                   0.50                      0
# 2                  2.0                   0.50                      0
# 3                  2.5                   0.70                      0
# 4                  2.0                   0.75                      0
